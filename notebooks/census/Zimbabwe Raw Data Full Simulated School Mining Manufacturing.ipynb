# %%
#install all required packages to run in this 
pip install -U setuptools
conda install pip
conda install git
conda install sphinx

# %%
conda install -c conda-forge ipylab
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::keyring==21.2.1=py38_0
#   - defaults/osx-64::pip==20.1.1=py38_1
#   - defaults/noarch::contextlib2==0.6.0.post1=py_0
#   - defaults/osx-64::matplotlib-base==3.2.2=py38h5670ca0_0
#   - defaults/osx-64::python-language-server==0.34.1=py38_0
#   - defaults/noarch::pygments==2.6.1=py_0
#   - defaults/osx-64::nose==1.3.7=py38_1004
#   - defaults/osx-64::xlwt==1.3.0=py38_0
#   - defaults/noarch::pyparsing==2.4.7=py_0
#   - defaults/osx-64::rtree==0.9.4=py38_1
#   - defaults/osx-64::pyyaml==5.3.1=py38haf1e3a3_1
#   - defaults/osx-64::jsonschema==3.2.0=py38_1
#   - defaults/osx-64::mkl_random==1.1.1=py38h959d312_0
#   - defaults/osx-64::asn1crypto==1.3.0=py38_1
#   - defaults/noarch::networkx==2.4=py_1
#   - defaults/osx-64::statsmodels==0.11.1=py38haf1e3a3_0
#   - defaults/osx-64::ptyprocess==0.6.0=py38_0
#   - defaults/noarch::python-libarchive-c==2.9=py_0
#   - defaults/noarch::soupsieve==2.0.1=py_0
#   - defaults/osx-64::astropy==4.0.1.post1=py38h01d97ff_1
#   - defaults/osx-64::pyqt==5.9.2=py38h655552a_2
#   - defaults/osx-64::pycosat==0.6.3=py38h1de35cc_1
#   - defaults/osx-64::kiwisolver==1.2.0=py38h04f5b5a_0
#   - defaults/noarch::sphinxcontrib-qthelp==1.0.3=py_0
#   - defaults/osx-64::simplegeneric==0.8.1=py38_2
#   - defaults/noarch::olefile==0.46=py_0
#   - defaults/noarch::sortedcontainers==2.2.2=py_0
#   - defaults/noarch::autopep8==1.5.3=py_0
#   - defaults/osx-64::jedi==0.17.1=py38_0
#   - defaults/noarch::nltk==3.5=py_0
#   - defaults/osx-64::certifi==2020.6.20=py38_0
#   - defaults/osx-64::get_terminal_size==1.0.0=h7520d66_0
#   - defaults/osx-64::cython==0.29.21=py38hb1e8313_0
#   - defaults/osx-64::numpy-base==1.18.5=py38h3304bdc_0
#   - defaults/noarch::backports.functools_lru_cache==1.6.1=py_0
#   - defaults/osx-64::bottleneck==1.3.2=py38hf1fa96c_1
#   - defaults/noarch::prometheus_client==0.8.0=py_0
#   - defaults/osx-64::pickleshare==0.7.5=py38_1001
#   - defaults/noarch::numpydoc==1.1.0=py_0
#   - defaults/osx-64::singledispatch==3.4.0.3=py38_0
#   - defaults/osx-64::conda-build==3.18.11=py38_0
#   - defaults/noarch::sphinxcontrib-serializinghtml==1.1.4=py_0
#   - defaults/osx-64::wrapt==1.11.2=py38h1de35cc_0
#   - defaults/osx-64::traitlets==4.3.3=py38_0
#   - defaults/noarch::werkzeug==1.0.1=py_0
#   - defaults/osx-64::pysocks==1.7.1=py38_1
#   - defaults/osx-64::sympy==1.6.1=py38_0
#   - defaults/osx-64::conda-package-handling==1.6.1=py38h1de35cc_0
#   - defaults/noarch::glob2==0.7=py_0
#   - defaults/osx-64::llvmlite==0.33.0=py38ha11be7d_1
#   - defaults/noarch::jupyter_console==6.1.0=py_0
#   - defaults/osx-64::sqlalchemy==1.3.18=py38haf1e3a3_0
#   - defaults/noarch::dask-core==2.20.0=py_0
#   - defaults/noarch::more-itertools==8.4.0=py_0
#   - defaults/osx-64::importlib-metadata==1.7.0=py38_0
#   - defaults/osx-64::entrypoints==0.3=py38_0
#   - defaults/osx-64::webencodings==0.5.1=py38_1
#   - defaults/noarch::qtawesome==0.7.2=py_0
#   - defaults/noarch::mock==4.0.2=py_0
#   - defaults/osx-64::isort==4.3.21=py38_0
#   - defaults/osx-64::appscript==1.1.1=py38haf1e3a3_0
#   - defaults/noarch::threadpoolctl==2.1.0=pyh5ca1d4c_0
#   - defaults/osx-64::docutils==0.16=py38_1
#   - defaults/noarch::atomicwrites==1.4.0=py_0
#   - defaults/noarch::imageio==2.9.0=py_0
#   - defaults/noarch::pydocstyle==5.0.2=py_0
#   - defaults/osx-64::backports.shutil_get_terminal_size==1.0.0=py38_2
#   - defaults/noarch::xlrd==1.2.0=py_0
#   - defaults/osx-64::sphinxcontrib==1.0=py38_1
#   - defaults/noarch::ipywidgets==7.5.1=py_0
#   - defaults/noarch::decorator==4.4.2=py_0
#   - defaults/osx-64::pyzmq==19.0.1=py38hb1e8313_1
#   - defaults/osx-64::argh==0.26.2=py38_0
#   - defaults/noarch::snowballstemmer==2.0.0=py_0
#   - defaults/osx-64::pywavelets==1.1.1=py38h1de35cc_0
#   - defaults/osx-64::chardet==3.0.4=py38_1003
#   - defaults/osx-64::send2trash==1.5.0=py38_0
#   - defaults/osx-64::pep8==1.7.1=py38_0
#   - defaults/noarch::xlsxwriter==1.2.9=py_0
#   - defaults/osx-64::mkl_fft==1.1.0=py38hc64f4ea_0
#   - defaults/noarch::json5==0.9.5=py_0
#   - defaults/noarch::anaconda-project==0.8.4=py_0
#   - defaults/noarch::backports==1.0=py_2
#   - defaults/osx-64::appnope==0.1.0=py38_1001
#   - defaults/noarch::partd==1.1.0=py_0
#   - defaults/noarch::python-jsonrpc-server==0.3.4=py_1
#   - defaults/osx-64::bokeh==2.1.1=py38_0
#   - defaults/osx-64::navigator-updater==0.2.1=py38_0
#   - defaults/osx-64::terminado==0.8.3=py38_0
#   - defaults/osx-64::beautifulsoup4==4.9.1=py38_0
#   - defaults/osx-64::scipy==1.5.0=py38hbab996c_0
#   - defaults/noarch::pyflakes==2.2.0=py_0
#   - defaults/noarch::importlib_metadata==1.7.0=0
#   - defaults/osx-64::pandocfilters==1.4.2=py38_1
#   - defaults/osx-64::zope.interface==4.7.1=py38h1de35cc_0
#   - defaults/noarch::sortedcollections==1.2.1=py_0
#   - defaults/noarch::itsdangerous==1.1.0=py_0
#   - defaults/noarch::toolz==0.10.0=py_0
#   - defaults/osx-64::wheel==0.34.2=py38_0
#   - defaults/osx-64::greenlet==0.4.16=py38haf1e3a3_0
#   - defaults/noarch::py==1.9.0=py_0
#   - defaults/noarch::testpath==0.4.4=py_0
#   - defaults/osx-64::boto==2.49.0=py38_0
#   - defaults/osx-64::patsy==0.5.1=py38_0
#   - defaults/noarch::intervaltree==3.0.2=py_1
#   - defaults/noarch::sphinxcontrib-devhelp==1.0.2=py_0
#   - defaults/osx-64::multipledispatch==0.6.0=py38_0
#   - conda-forge/noarch::ipython-autotime==0.1=py_1
#   - defaults/osx-64::unicodecsv==0.14.1=py38_0
#   - defaults/osx-64::cryptography==2.9.2=py38ha12b0ac_0
#   - defaults/noarch::jinja2==2.11.2=py_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py38_0
#   - defaults/noarch::tblib==1.6.0=py_0
#   - defaults/osx-64::msgpack-python==1.0.0=py38h04f5b5a_1
#   - defaults/osx-64::anaconda-client==1.7.2=py38_0
#   - defaults/osx-64::anaconda==2020.07=py38_0
#   - defaults/osx-64::spyder==4.1.4=py38_0
#   - defaults/osx-64::pillow==7.2.0=py38ha54b6ba_0
#   - defaults/osx-64::numba==0.50.1=py38h959d312_1
#   - defaults/osx-64::mccabe==0.6.1=py38_1
#   - defaults/osx-64::distributed==2.20.0=py38_0
#   - defaults/osx-64::numexpr==2.7.1=py38hce01a72_0
#   - defaults/noarch::sphinxcontrib-htmlhelp==1.0.3=py_0
#   - defaults/osx-64::jupyter_core==4.6.3=py38_0
#   - defaults/osx-64::xlwings==0.19.5=py38_0
#   - defaults/noarch::backports.tempfile==1.0=py_1
#   - defaults/noarch::six==1.15.0=py_0
#   - defaults/noarch::idna==2.10=py_0
#   - defaults/osx-64::pylint==2.5.3=py38_0
#   - defaults/osx-64::brotlipy==0.7.0=py38haf1e3a3_1000
#   - defaults/noarch::sphinx==3.1.2=py_0
#   - defaults/osx-64::pyodbc==4.0.30=py38h0a44026_0
#   - defaults/noarch::packaging==20.4=py_0
#   - defaults/noarch::yapf==0.30.0=py_0
#   - defaults/noarch::path.py==12.4.0=0
#   - defaults/noarch::jupyter_client==6.1.6=py_0
#   - defaults/noarch::openpyxl==3.0.4=py_0
#   - defaults/noarch::wcwidth==0.2.5=py_0
#   - defaults/osx-64::ipykernel==5.3.2=py38h5ca1d4c_0
#   - defaults/osx-64::cycler==0.10.0=py38_0
#   - defaults/osx-64::regex==2020.6.8=py38haf1e3a3_0
#   - defaults/osx-64::pycurl==7.43.0.5=py38ha12b0ac_0
#   - defaults/noarch::nbformat==5.0.7=py_0
#   - conda-forge/osx-64::python_abi==3.8=1_cp38
#   - defaults/osx-64::mistune==0.8.4=py38h1de35cc_1001
#   - defaults/noarch::urllib3==1.25.9=py_0
#   - defaults/noarch::defusedxml==0.6.0=py_0
#   - defaults/osx-64::widgetsnbextension==3.5.1=py38_0
#   - defaults/noarch::colorama==0.4.3=py_0
#   - defaults/osx-64::pytest==5.4.3=py38_0
#   - defaults/noarch::dask==2.20.0=py_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/noarch::parso==0.7.0=py_0
#   - defaults/osx-64::clyent==1.2.2=py38_1
#   - defaults/osx-64::astroid==2.4.2=py38_0
#   - defaults/noarch::cloudpickle==1.5.0=py_0
#   - defaults/noarch::pyopenssl==19.1.0=py_1
#   - defaults/noarch::alabaster==0.7.12=py_0
#   - defaults/noarch::pytz==2020.1=py_0
#   - defaults/noarch::fsspec==0.7.4=py_0
#   - defaults/osx-64::psutil==5.7.0=py38h1de35cc_0
#   - defaults/noarch::pathtools==0.1.2=py_1
#   - defaults/noarch::babel==2.8.0=py_0
#   - defaults/osx-64::pyrsistent==0.16.0=py38h1de35cc_0
#   - defaults/noarch::sphinxcontrib-websupport==1.2.3=py_0
#   - defaults/osx-64::ipython==7.16.1=py38h5ca1d4c_0
#   - defaults/osx-64::markupsafe==1.1.1=py38h1de35cc_1
#   - defaults/noarch::jupyterlab_server==1.2.0=py_0
#   - defaults/noarch::attrs==19.3.0=py_0
#   - defaults/osx-64::pkginfo==1.5.0.1=py38_0
#   - defaults/osx-64::gevent==20.6.2=py38haf1e3a3_0
#   - defaults/osx-64::locket==0.2.0=py38_1
#   - defaults/osx-64::pathlib2==2.3.5=py38_1
#   - defaults/osx-64::notebook==6.0.3=py38_0
#   - defaults/osx-64::h5py==2.10.0=py38h3134771_0
#   - defaults/osx-64::watchdog==0.10.3=py38haf1e3a3_0
#   - defaults/noarch::heapdict==1.0.1=py_0
#   - defaults/noarch::diff-match-patch==20200713=py_0
#   - defaults/noarch::toml==0.10.1=py_0
#   - defaults/noarch::sphinxcontrib-applehelp==1.0.2=py_0
#   - defaults/noarch::typing_extensions==3.7.4.2=py_0
#   - defaults/osx-64::ruamel_yaml==0.15.87=py38haf1e3a3_1
#   - defaults/noarch::qdarkstyle==2.8.1=py_0
#   - defaults/osx-64::jupyter==1.0.0=py38_7
#   - defaults/osx-64::gmpy2==2.0.8=py38h6ef4df4_3
#   - defaults/osx-64::scikit-image==0.16.2=py38h6c726b0_0
#   - defaults/osx-64::py-lief==0.10.1=py38haf313ee_0
#   - defaults/osx-64::path==13.1.0=py38_0
#   - defaults/noarch::pycparser==2.20=py_2
#   - defaults/noarch::pycodestyle==2.6.0=py_0
#   - defaults/osx-64::cytoolz==0.10.1=py38h1de35cc_0
#   - defaults/noarch::qtconsole==4.7.5=py_0
#   - defaults/noarch::seaborn==0.10.1=py_0
#   - defaults/noarch::et_xmlfile==1.0.1=py_1001
#   - defaults/noarch::tqdm==4.47.0=py_0
#   - defaults/osx-64::wurlitzer==2.0.1=py38_0
#   - defaults/osx-64::scikit-learn==0.23.1=py38h603561c_0
#   - defaults/noarch::rope==0.17.0=py_0
#   - defaults/noarch::click==7.1.2=py_0
#   - defaults/osx-64::bkcharts==0.2=py38_0
#   - defaults/noarch::xmltodict==0.12.0=py_0
#   - defaults/osx-64::python.app==2=py38_10
#   - defaults/noarch::backcall==0.2.0=py_0
#   - defaults/osx-64::numpy==1.18.5=py38h1da2735_0
#   - defaults/noarch::jdcal==1.4.1=py_0
#   - defaults/osx-64::python==3.8.3=h26836e1_2
#   - defaults/osx-64::fastcache==1.1.0=py38h1de35cc_0
#   - defaults/osx-64::matplotlib==3.2.2=0
#   - defaults/noarch::sphinxcontrib-jsmath==1.0.1=py_0
#   - defaults/osx-64::anaconda-navigator==1.9.12=py38_0
#   - defaults/noarch::jupyterlab==2.1.5=py_0
#   - defaults/osx-64::cffi==1.14.0=py38hc512035_1
#   - defaults/osx-64::ply==3.11=py38_0
#   - defaults/osx-64::pluggy==0.13.1=py38_0
#   - defaults/osx-64::bitarray==1.4.0=py38haf1e3a3_0
#   - defaults/noarch::applaunchservices==0.2.1=py_0
#   - defaults/noarch::zipp==3.1.0=py_0
#   - defaults/noarch::requests==2.24.0=py_0
#   - defaults/osx-64::zope==1.0=py38_1
#   - defaults/noarch::flask==1.1.2=py_0
#   - defaults/osx-64::nbconvert==5.6.1=py38_1
#   - defaults/osx-64::sip==4.19.8=py38h0a44026_0
#   - defaults/noarch::bleach==3.1.5=py_0
#   - defaults/osx-64::conda==4.8.4=py38_0
#   - defaults/osx-64::lxml==4.5.2=py38h63b7cb6_0
#   - defaults/osx-64::tornado==6.0.4=py38h1de35cc_1
#   - defaults/noarch::imagesize==1.2.0=py_0
#   - defaults/osx-64::lazy-object-proxy==1.4.3=py38h1de35cc_0
#   - defaults/noarch::filelock==3.0.12=py_0
#   - defaults/noarch::html5lib==1.1=py_0
#   - defaults/osx-64::ujson==1.35=py38h1de35cc_0
#   - defaults/noarch::flake8==3.8.3=py_0
#   - defaults/osx-64::zope.event==4.4=py38_0
#   - defaults/osx-64::mpmath==1.1.0=py38_0
#   - defaults/noarch::joblib==0.16.0=py_0
#   - defaults/osx-64::spyder-kernels==1.9.2=py38_0
#   - defaults/noarch::prompt_toolkit==3.0.5=0
#   - defaults/osx-64::pexpect==4.8.0=py38_1
#   - defaults/noarch::python-dateutil==2.8.1=py_0
#   - defaults/noarch::prompt-toolkit==3.0.5=py_0
#   - defaults/noarch::backports.weakref==1.0.post1=py_1
#   - defaults/osx-64::pytables==3.6.1=py38h4727e94_0
#   - defaults/osx-64::ipython_genutils==0.2.0=py38_0
#   - defaults/noarch::qtpy==1.9.0=py_0
#   - defaults/osx-64::mkl-service==2.3.0=py38hfbe908c_0
#   - defaults/osx-64::future==0.18.2=py38_1
#   - defaults/noarch::zict==2.0.0=py_0
# done
#
# ## Package Plan ##
#
#   environment location: /Applications/anaconda3
#
#   added / updated specs:
#     - ipylab
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ipylab-0.3.0               |             py_0           8 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:           8 KB
#
# The following NEW packages will be INSTALLED:
#
#   ipylab             conda-forge/noarch::ipylab-0.3.0-py_0
#   pandas             pkgs/main/osx-64::pandas-1.0.5-py38h959d312_0
#   setuptools         pkgs/main/osx-64::setuptools-49.2.0-py38_0
#
#
#
# Downloading and Extracting Packages
# ipylab-0.3.0         | 8 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: failed
#
# RemoveError: 'setuptools' is a dependency of conda and cannot be removed from
# conda's operating environment.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda list
# Out:
# # packages in environment at /Applications/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py38_0
# absl-py                   0.9.0                    pypi_0    pypi
# alabaster                 0.7.12                     py_0
# anaconda                  2020.07                  py38_0
# anaconda-client           1.7.2                    py38_0
# anaconda-navigator        1.9.12                   py38_0
# anaconda-project          0.8.4                      py_0
# applaunchservices         0.2.1                      py_0
# appnope                   0.1.0                 py38_1001
# appscript                 1.1.1            py38haf1e3a3_0
# argh                      0.26.2                   py38_0
# art                       4.7                      pypi_0    pypi
# asn1crypto                1.3.0                    py38_1
# astroid                   2.4.2                    py38_0
# astropy                   4.0.1.post1      py38h01d97ff_1
# astunparse                1.6.3                    pypi_0    pypi
# atomicwrites              1.4.0                      py_0
# attrs                     19.3.0                     py_0
# autopep8                  1.5.3                      py_0
# babel                     2.8.0                      py_0
# backcall                  0.2.0                      py_0
# backports                 1.0                        py_2
# backports.functools_lru_cache 1.6.1                      py_0
# backports.shutil_get_terminal_size 1.0.0                    py38_2
# backports.tempfile        1.0                        py_1
# backports.weakref         1.0.post1                  py_1
# beautifulsoup4            4.9.1                    py38_0
# bitarray                  1.4.0            py38haf1e3a3_0
# bkcharts                  0.2                      py38_0
# blas                      1.0                         mkl
# bleach                    3.1.5                      py_0
# blosc                     1.19.0               hab81aa3_0
# bokeh                     2.1.1                    py38_0
# boto                      2.49.0                   py38_0
# bottleneck                1.3.2            py38hf1fa96c_1
# brotlipy                  0.7.0           py38haf1e3a3_1000
# bzip2                     1.0.8                h1de35cc_0
# ca-certificates           2020.6.24                     0
# cachetools                4.1.1                    pypi_0    pypi
# certifi                   2020.6.20                py38_0
# cffi                      1.14.0           py38hc512035_1
# chardet                   3.0.4                 py38_1003
# click                     7.1.2                      py_0
# cloudpickle               1.5.0                      py_0
# clyent                    1.2.2                    py38_1
# cmdstanpy                 0.4.0                    pypi_0    pypi
# colorama                  0.4.3                      py_0
# conda                     4.8.4                    py38_0
# conda-build               3.18.11                  py38_0
# conda-env                 2.6.0                         1
# conda-package-handling    1.6.1            py38h1de35cc_0
# conda-verify              3.4.2                      py_1
# contextlib2               0.6.0.post1                py_0
# convertdate               2.2.1                    pypi_0    pypi
# cryptography              2.9.2            py38ha12b0ac_0
# curl                      7.71.1               hb0a8c7a_1
# cycler                    0.10.0                   py38_0
# cython                    0.29.21          py38hb1e8313_0
# cytoolz                   0.10.1           py38h1de35cc_0
# dask                      2.20.0                     py_0
# dask-core                 2.20.0                     py_0
# dbus                      1.13.16              h18a8e69_0
# decorator                 4.4.2                      py_0
# defusedxml                0.6.0                      py_0
# diff-match-patch          20200713                   py_0
# distributed               2.20.0                   py38_0
# dnntime                   0.4.1                    pypi_0    pypi
# docutils                  0.16                     py38_1
# entrypoints               0.3                      py38_0
# ephem                     3.7.7.1                  pypi_0    pypi
# et_xmlfile                1.0.1                   py_1001
# expat                     2.2.9                hb1e8313_2
# fastcache                 1.1.0            py38h1de35cc_0
# fbprophet                 0.6                      pypi_0    pypi
# filelock                  3.0.12                     py_0
# flake8                    3.8.3                      py_0
# flask                     1.1.2                      py_0
# freetype                  2.10.2               ha233b18_0
# fsspec                    0.7.4                      py_0
# future                    0.18.2                   py38_1
# gast                      0.3.3                    pypi_0    pypi
# get_terminal_size         1.0.0                h7520d66_0
# gettext                   0.19.8.1             hb0f4f8b_2
# gevent                    20.6.2           py38haf1e3a3_0
# git                       2.23.0          pl526h6951d83_0
# glib                      2.65.0               hc5f4afa_0
# glob2                     0.7                        py_0
# gmp                       6.1.2                hb37e062_1
# gmpy2                     2.0.8            py38h6ef4df4_3
# google-auth               1.20.1                   pypi_0    pypi
# google-auth-oauthlib      0.4.1                    pypi_0    pypi
# google-pasta              0.2.0                    pypi_0    pypi
# greenlet                  0.4.16           py38haf1e3a3_0
# grpcio                    1.31.0                   pypi_0    pypi
# h5py                      2.10.0           py38h3134771_0
# hdf5                      1.10.4               hfa1e0ec_0
# heapdict                  1.0.1                      py_0
# holidays                  0.10.3                   pypi_0    pypi
# html5lib                  1.1                        py_0
# icu                       58.2                 h0a44026_3
# idna                      2.10                       py_0
# imageio                   2.9.0                      py_0
# imagesize                 1.2.0                      py_0
# importlib-metadata        1.7.0                    py38_0
# importlib_metadata        1.7.0                         0
# intel-openmp              2019.4                      233
# intervaltree              3.0.2                      py_1
# ipykernel                 5.3.2            py38h5ca1d4c_0
# ipython                   7.16.1           py38h5ca1d4c_0
# ipython-autotime          0.1                        py_1    conda-forge
# ipython_genutils          0.2.0                    py38_0
# ipywidgets                7.5.1                      py_0
# isort                     4.3.21                   py38_0
# itsdangerous              1.1.0                      py_0
# jbig                      2.1                  h4d881f8_0
# jdcal                     1.4.1                      py_0
# jedi                      0.17.1                   py38_0
# jinja2                    2.11.2                     py_0
# joblib                    0.16.0                     py_0
# jpeg                      9b                   he5867d9_2
# json5                     0.9.5                      py_0
# jsonschema                3.2.0                    py38_1
# jupyter                   1.0.0                    py38_7
# jupyter_client            6.1.6                      py_0
# jupyter_console           6.1.0                      py_0
# jupyter_core              4.6.3                    py38_0
# jupyterlab                2.1.5                      py_0
# jupyterlab_server         1.2.0                      py_0
# keras-preprocessing       1.1.2                    pypi_0    pypi
# keyring                   21.2.1                   py38_0
# kiwisolver                1.2.0            py38h04f5b5a_0
# korean-lunar-calendar     0.2.1                    pypi_0    pypi
# krb5                      1.18.2               h75d18d8_0
# lazy-object-proxy         1.4.3            py38h1de35cc_0
# lcms2                     2.11                 h92f6f08_0
# libarchive                3.4.2                haa3ed63_0
# libcurl                   7.71.1               h8a08a2b_1
# libcxx                    10.0.0                        1
# libedit                   3.1.20191231         h1de35cc_1
# libffi                    3.3                  hb1e8313_2
# libgfortran               3.0.1                h93005f0_2
# libiconv                  1.16                 h1de35cc_0
# liblief                   0.10.1               h0a44026_0
# libllvm9                  9.0.1                h21ff451_1
# libpng                    1.6.37               ha441bb4_0
# libsodium                 1.0.18               h1de35cc_0
# libspatialindex           1.9.3                h0a44026_0
# libssh2                   1.9.0                ha12b0ac_1
# libtiff                   4.1.0                hcb84e12_1
# libxml2                   2.9.10               h3b9e6c8_1
# libxslt                   1.1.34               h83b36ba_0
# llvm-openmp               10.0.0               h28b9765_0
# llvmlite                  0.33.0           py38ha11be7d_1
# locket                    0.2.0                    py38_1
# lunarcalendar             0.0.9                    pypi_0    pypi
# lxml                      4.5.2            py38h63b7cb6_0
# lz4-c                     1.9.2                h0a44026_0
# lzo                       2.10                 h1de35cc_2
# markdown                  3.2.2                    pypi_0    pypi
# markupsafe                1.1.1            py38h1de35cc_1
# matplotlib                3.2.2                         0
# matplotlib-base           3.2.2            py38h5670ca0_0
# mccabe                    0.6.1                    py38_1
# mistune                   0.8.4           py38h1de35cc_1001
# mkl                       2019.4                      233
# mkl-service               2.3.0            py38hfbe908c_0
# mkl_fft                   1.1.0            py38hc64f4ea_0
# mkl_random                1.1.1            py38h959d312_0
# mock                      4.0.2                      py_0
# more-itertools            8.4.0                      py_0
# mpc                       1.1.0                h6ef4df4_1
# mpfr                      4.0.2                h9066e36_1
# mpmath                    1.1.0                    py38_0
# msgpack-python            1.0.0            py38h04f5b5a_1
# multipledispatch          0.6.0                    py38_0
# navigator-updater         0.2.1                    py38_0
# nbconvert                 5.6.1                    py38_1
# nbformat                  5.0.7                      py_0
# ncurses                   6.2                  h0a44026_1
# networkx                  2.4                        py_1
# nltk                      3.5                        py_0
# nose                      1.3.7                 py38_1004
# notebook                  6.0.3                    py38_0
# numba                     0.50.1           py38h959d312_1
# numdifftools              0.9.39                   pypi_0    pypi
# numexpr                   2.7.1            py38hce01a72_0
# numpy                     1.18.5           py38h1da2735_0
# numpy-base                1.18.5           py38h3304bdc_0
# numpydoc                  1.1.0                      py_0
# oauthlib                  3.1.0                    pypi_0    pypi
# olefile                   0.46                       py_0
# openpyxl                  3.0.4                      py_0
# openssl                   1.1.1g               h1de35cc_0
# opt-einsum                3.3.0                    pypi_0    pypi
# packaging                 20.4                       py_0
# pandas                    0.25.3                   pypi_0    pypi
# pandoc                    2.10                          0
# pandocfilters             1.4.2                    py38_1
# parso                     0.7.0                      py_0
# partd                     1.1.0                      py_0
# path                      13.1.0                   py38_0
# path.py                   12.4.0                        0
# pathlib2                  2.3.5                    py38_1
# pathtools                 0.1.2                      py_1
# patsy                     0.5.1                    py38_0
# pcre                      8.44                 hb1e8313_0
# pep8                      1.7.1                    py38_0
# perl                      5.26.2               h4e221da_0
# pexpect                   4.8.0                    py38_1
# pickleshare               0.7.5                 py38_1001
# pillow                    7.2.0            py38ha54b6ba_0
# pip                       20.1.1                   py38_1
# pkginfo                   1.5.0.1                  py38_0
# plotly                    4.9.0                    pypi_0    pypi
# pluggy                    0.13.1                   py38_0
# ply                       3.11                     py38_0
# prometheus_client         0.8.0                      py_0
# prompt-toolkit            3.0.5                      py_0
# prompt_toolkit            3.0.5                         0
# protobuf                  3.13.0                   pypi_0    pypi
# psutil                    5.7.0            py38h1de35cc_0
# ptyprocess                0.6.0                    py38_0
# py                        1.9.0                      py_0
# py-lief                   0.10.1           py38haf313ee_0
# pyasn1                    0.4.8                    pypi_0    pypi
# pyasn1-modules            0.2.8                    pypi_0    pypi
# pycodestyle               2.6.0                      py_0
# pycosat                   0.6.3            py38h1de35cc_1
# pycparser                 2.20                       py_2
# pycurl                    7.43.0.5         py38ha12b0ac_0
# pydocstyle                5.0.2                      py_0
# pyflakes                  2.2.0                      py_0
# pygments                  2.6.1                      py_0
# pylint                    2.5.3                    py38_0
# pymeeus                   0.3.7                    pypi_0    pypi
# pyodbc                    4.0.30           py38h0a44026_0
# pyopenssl                 19.1.0                     py_1
# pyparsing                 2.4.7                      py_0
# pyqt                      5.9.2            py38h655552a_2
# pyrsistent                0.16.0           py38h1de35cc_0
# pysocks                   1.7.1                    py38_1
# pystan                    2.19.1.1                 pypi_0    pypi
# pytables                  3.6.1            py38h4727e94_0
# pytest                    5.4.3                    py38_0
# python                    3.8.3                h26836e1_2
# python-dateutil           2.8.1                      py_0
# python-jsonrpc-server     0.3.4                      py_1
# python-language-server    0.34.1                   py38_0
# python-libarchive-c       2.9                        py_0
# python.app                2                       py38_10
# python_abi                3.8                      1_cp38    conda-forge
# pytz                      2020.1                     py_0
# pywavelets                1.1.1            py38h1de35cc_0
# pyyaml                    5.3.1            py38haf1e3a3_1
# pyzmq                     19.0.1           py38hb1e8313_1
# qdarkstyle                2.8.1                      py_0
# qt                        5.9.7                h468cd18_1
# qtawesome                 0.7.2                      py_0
# qtconsole                 4.7.5                      py_0
# qtpy                      1.9.0                      py_0
# readline                  8.0                  h1de35cc_0
# regex                     2020.6.8         py38haf1e3a3_0
# requests                  2.24.0                     py_0
# requests-oauthlib         1.3.0                    pypi_0    pypi
# retrying                  1.3.3                    pypi_0    pypi
# ripgrep                   11.0.2               he32d670_0
# rope                      0.17.0                     py_0
# rsa                       4.6                      pypi_0    pypi
# rtree                     0.9.4                    py38_1
# ruamel_yaml               0.15.87          py38haf1e3a3_1
# scikit-image              0.16.2           py38h6c726b0_0
# scikit-learn              0.23.1           py38h603561c_0
# scipy                     1.5.0            py38hbab996c_0
# seaborn                   0.10.1                     py_0
# send2trash                1.5.0                    py38_0
# setuptools                49.6.0                   pypi_0    pypi
# setuptools-git            1.2                      pypi_0    pypi
# simplegeneric             0.8.1                    py38_2
# singledispatch            3.4.0.3                  py38_0
# sip                       4.19.8           py38h0a44026_0
# six                       1.15.0                     py_0
# snappy                    1.1.8                hb1e8313_0
# snowballstemmer           2.0.0                      py_0
# sortedcollections         1.2.1                      py_0
# sortedcontainers          2.2.2                      py_0
# soupsieve                 2.0.1                      py_0
# sphinx                    3.1.2                      py_0
# sphinxcontrib             1.0                      py38_1
# sphinxcontrib-applehelp   1.0.2                      py_0
# sphinxcontrib-devhelp     1.0.2                      py_0
# sphinxcontrib-htmlhelp    1.0.3                      py_0
# sphinxcontrib-jsmath      1.0.1                      py_0
# sphinxcontrib-qthelp      1.0.3                      py_0
# sphinxcontrib-serializinghtml 1.1.4                      py_0
# sphinxcontrib-websupport  1.2.3                      py_0
# spyder                    4.1.4                    py38_0
# spyder-kernels            1.9.2                    py38_0
# sqlalchemy                1.3.18           py38haf1e3a3_0
# sqlite                    3.32.3               hffcf06c_0
# statsmodels               0.11.1           py38haf1e3a3_0
# sympy                     1.6.1                    py38_0
# tbb                       2020.0               h04f5b5a_0
# tblib                     1.6.0                      py_0
# tensorboard               2.3.0                    pypi_0    pypi
# tensorboard-plugin-wit    1.7.0                    pypi_0    pypi
# tensorflow                2.3.0                    pypi_0    pypi
# tensorflow-estimator      2.3.0                    pypi_0    pypi
# termcolor                 1.1.0                    pypi_0    pypi
# terminado                 0.8.3                    py38_0
# testpath                  0.4.4                      py_0
# threadpoolctl             2.1.0              pyh5ca1d4c_0
# tk                        8.6.10               hb0a8c7a_0
# toml                      0.10.1                     py_0
# toolz                     0.10.0                     py_0
# tornado                   6.0.4            py38h1de35cc_1
# tqdm                      4.47.0                     py_0
# traitlets                 4.3.3                    py38_0
# tscv                      0.0.4                    pypi_0    pypi
# typing_extensions         3.7.4.2                    py_0
# ujson                     1.35             py38h1de35cc_0
# unicodecsv                0.14.1                   py38_0
# unixodbc                  2.3.7                h1de35cc_0
# urllib3                   1.25.9                     py_0
# watchdog                  0.10.3           py38haf1e3a3_0
# wcwidth                   0.2.5                      py_0
# webencodings              0.5.1                    py38_1
# werkzeug                  1.0.1                      py_0
# wheel                     0.34.2                   py38_0
# widgetsnbextension        3.5.1                    py38_0
# wrapt                     1.11.2           py38h1de35cc_0
# wurlitzer                 2.0.1                    py38_0
# xlrd                      1.2.0                      py_0
# xlsxwriter                1.2.9                      py_0
# xlwings                   0.19.5                   py38_0
# xlwt                      1.3.0                    py38_0
# xmltodict                 0.12.0                     py_0
# xz                        5.2.5                h1de35cc_0
# yaml                      0.2.5                haf1e3a3_0
# yapf                      0.30.0                     py_0
# zeromq                    4.3.2                hb1e8313_2
# zict                      2.0.0                      py_0
# zipp                      3.1.0                      py_0
# zlib                      1.2.11               h1de35cc_3
# zope                      1.0                      py38_1
# zope.event                4.4                      py38_0
# zope.interface            4.7.1            py38h1de35cc_0
# zstd                      1.4.5                h41d2c2f_0
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge jsonschema
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::keyring==21.2.1=py38_0
#   - defaults/osx-64::pip==20.1.1=py38_1
#   - defaults/noarch::contextlib2==0.6.0.post1=py_0
#   - defaults/osx-64::matplotlib-base==3.2.2=py38h5670ca0_0
#   - defaults/osx-64::python-language-server==0.34.1=py38_0
#   - defaults/noarch::pygments==2.6.1=py_0
#   - defaults/osx-64::nose==1.3.7=py38_1004
#   - defaults/osx-64::xlwt==1.3.0=py38_0
#   - defaults/noarch::pyparsing==2.4.7=py_0
#   - defaults/osx-64::rtree==0.9.4=py38_1
#   - defaults/osx-64::pyyaml==5.3.1=py38haf1e3a3_1
#   - defaults/osx-64::jsonschema==3.2.0=py38_1
#   - defaults/osx-64::mkl_random==1.1.1=py38h959d312_0
#   - defaults/osx-64::asn1crypto==1.3.0=py38_1
#   - defaults/noarch::networkx==2.4=py_1
#   - defaults/osx-64::statsmodels==0.11.1=py38haf1e3a3_0
#   - defaults/osx-64::ptyprocess==0.6.0=py38_0
#   - defaults/noarch::python-libarchive-c==2.9=py_0
#   - defaults/noarch::soupsieve==2.0.1=py_0
#   - defaults/osx-64::astropy==4.0.1.post1=py38h01d97ff_1
#   - defaults/osx-64::pyqt==5.9.2=py38h655552a_2
#   - defaults/osx-64::pycosat==0.6.3=py38h1de35cc_1
#   - defaults/osx-64::kiwisolver==1.2.0=py38h04f5b5a_0
#   - defaults/noarch::sphinxcontrib-qthelp==1.0.3=py_0
#   - defaults/osx-64::simplegeneric==0.8.1=py38_2
#   - defaults/noarch::olefile==0.46=py_0
#   - defaults/noarch::sortedcontainers==2.2.2=py_0
#   - defaults/noarch::autopep8==1.5.3=py_0
#   - defaults/osx-64::jedi==0.17.1=py38_0
#   - defaults/noarch::nltk==3.5=py_0
#   - defaults/osx-64::certifi==2020.6.20=py38_0
#   - defaults/osx-64::get_terminal_size==1.0.0=h7520d66_0
#   - defaults/osx-64::cython==0.29.21=py38hb1e8313_0
#   - defaults/osx-64::numpy-base==1.18.5=py38h3304bdc_0
#   - defaults/noarch::backports.functools_lru_cache==1.6.1=py_0
#   - defaults/osx-64::bottleneck==1.3.2=py38hf1fa96c_1
#   - defaults/noarch::prometheus_client==0.8.0=py_0
#   - defaults/osx-64::pickleshare==0.7.5=py38_1001
#   - defaults/noarch::numpydoc==1.1.0=py_0
#   - defaults/osx-64::singledispatch==3.4.0.3=py38_0
#   - defaults/osx-64::conda-build==3.18.11=py38_0
#   - defaults/noarch::sphinxcontrib-serializinghtml==1.1.4=py_0
#   - defaults/osx-64::wrapt==1.11.2=py38h1de35cc_0
#   - defaults/osx-64::traitlets==4.3.3=py38_0
#   - defaults/noarch::werkzeug==1.0.1=py_0
#   - defaults/osx-64::pysocks==1.7.1=py38_1
#   - defaults/osx-64::sympy==1.6.1=py38_0
#   - defaults/osx-64::conda-package-handling==1.6.1=py38h1de35cc_0
#   - defaults/noarch::glob2==0.7=py_0
#   - defaults/osx-64::llvmlite==0.33.0=py38ha11be7d_1
#   - defaults/noarch::jupyter_console==6.1.0=py_0
#   - defaults/osx-64::sqlalchemy==1.3.18=py38haf1e3a3_0
#   - defaults/noarch::dask-core==2.20.0=py_0
#   - defaults/noarch::more-itertools==8.4.0=py_0
#   - defaults/osx-64::importlib-metadata==1.7.0=py38_0
#   - defaults/osx-64::entrypoints==0.3=py38_0
#   - defaults/osx-64::webencodings==0.5.1=py38_1
#   - defaults/noarch::qtawesome==0.7.2=py_0
#   - defaults/noarch::mock==4.0.2=py_0
#   - defaults/osx-64::isort==4.3.21=py38_0
#   - defaults/osx-64::appscript==1.1.1=py38haf1e3a3_0
#   - defaults/noarch::threadpoolctl==2.1.0=pyh5ca1d4c_0
#   - defaults/osx-64::docutils==0.16=py38_1
#   - defaults/noarch::atomicwrites==1.4.0=py_0
#   - defaults/noarch::imageio==2.9.0=py_0
#   - defaults/noarch::pydocstyle==5.0.2=py_0
#   - defaults/osx-64::backports.shutil_get_terminal_size==1.0.0=py38_2
#   - defaults/noarch::xlrd==1.2.0=py_0
#   - defaults/osx-64::sphinxcontrib==1.0=py38_1
#   - defaults/noarch::ipywidgets==7.5.1=py_0
#   - defaults/noarch::decorator==4.4.2=py_0
#   - defaults/osx-64::pyzmq==19.0.1=py38hb1e8313_1
#   - defaults/osx-64::argh==0.26.2=py38_0
#   - defaults/noarch::snowballstemmer==2.0.0=py_0
#   - defaults/osx-64::pywavelets==1.1.1=py38h1de35cc_0
#   - defaults/osx-64::chardet==3.0.4=py38_1003
#   - defaults/osx-64::send2trash==1.5.0=py38_0
#   - defaults/osx-64::pep8==1.7.1=py38_0
#   - defaults/noarch::xlsxwriter==1.2.9=py_0
#   - defaults/osx-64::mkl_fft==1.1.0=py38hc64f4ea_0
#   - defaults/noarch::json5==0.9.5=py_0
#   - defaults/noarch::anaconda-project==0.8.4=py_0
#   - defaults/noarch::backports==1.0=py_2
#   - defaults/osx-64::appnope==0.1.0=py38_1001
#   - defaults/noarch::partd==1.1.0=py_0
#   - defaults/noarch::python-jsonrpc-server==0.3.4=py_1
#   - defaults/osx-64::bokeh==2.1.1=py38_0
#   - defaults/osx-64::navigator-updater==0.2.1=py38_0
#   - defaults/osx-64::terminado==0.8.3=py38_0
#   - defaults/osx-64::beautifulsoup4==4.9.1=py38_0
#   - defaults/osx-64::scipy==1.5.0=py38hbab996c_0
#   - defaults/noarch::pyflakes==2.2.0=py_0
#   - defaults/noarch::importlib_metadata==1.7.0=0
#   - defaults/osx-64::pandocfilters==1.4.2=py38_1
#   - defaults/osx-64::zope.interface==4.7.1=py38h1de35cc_0
#   - defaults/noarch::sortedcollections==1.2.1=py_0
#   - defaults/noarch::itsdangerous==1.1.0=py_0
#   - defaults/noarch::toolz==0.10.0=py_0
#   - defaults/osx-64::wheel==0.34.2=py38_0
#   - defaults/osx-64::greenlet==0.4.16=py38haf1e3a3_0
#   - defaults/noarch::py==1.9.0=py_0
#   - defaults/noarch::testpath==0.4.4=py_0
#   - defaults/osx-64::boto==2.49.0=py38_0
#   - defaults/osx-64::patsy==0.5.1=py38_0
#   - defaults/noarch::intervaltree==3.0.2=py_1
#   - defaults/noarch::sphinxcontrib-devhelp==1.0.2=py_0
#   - defaults/osx-64::multipledispatch==0.6.0=py38_0
#   - conda-forge/noarch::ipython-autotime==0.1=py_1
#   - defaults/osx-64::unicodecsv==0.14.1=py38_0
#   - defaults/osx-64::cryptography==2.9.2=py38ha12b0ac_0
#   - defaults/noarch::jinja2==2.11.2=py_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py38_0
#   - defaults/noarch::tblib==1.6.0=py_0
#   - defaults/osx-64::msgpack-python==1.0.0=py38h04f5b5a_1
#   - defaults/osx-64::anaconda-client==1.7.2=py38_0
#   - defaults/osx-64::anaconda==2020.07=py38_0
#   - defaults/osx-64::spyder==4.1.4=py38_0
#   - defaults/osx-64::pillow==7.2.0=py38ha54b6ba_0
#   - defaults/osx-64::numba==0.50.1=py38h959d312_1
#   - defaults/osx-64::mccabe==0.6.1=py38_1
#   - defaults/osx-64::distributed==2.20.0=py38_0
#   - defaults/osx-64::numexpr==2.7.1=py38hce01a72_0
#   - defaults/noarch::sphinxcontrib-htmlhelp==1.0.3=py_0
#   - defaults/osx-64::jupyter_core==4.6.3=py38_0
#   - defaults/osx-64::xlwings==0.19.5=py38_0
#   - defaults/noarch::backports.tempfile==1.0=py_1
#   - defaults/noarch::six==1.15.0=py_0
#   - defaults/noarch::idna==2.10=py_0
#   - defaults/osx-64::pylint==2.5.3=py38_0
#   - defaults/osx-64::brotlipy==0.7.0=py38haf1e3a3_1000
#   - defaults/noarch::sphinx==3.1.2=py_0
#   - defaults/osx-64::pyodbc==4.0.30=py38h0a44026_0
#   - defaults/noarch::packaging==20.4=py_0
#   - defaults/noarch::yapf==0.30.0=py_0
#   - defaults/noarch::path.py==12.4.0=0
#   - defaults/noarch::jupyter_client==6.1.6=py_0
#   - defaults/noarch::openpyxl==3.0.4=py_0
#   - defaults/noarch::wcwidth==0.2.5=py_0
#   - defaults/osx-64::ipykernel==5.3.2=py38h5ca1d4c_0
#   - defaults/osx-64::cycler==0.10.0=py38_0
#   - defaults/osx-64::regex==2020.6.8=py38haf1e3a3_0
#   - defaults/osx-64::pycurl==7.43.0.5=py38ha12b0ac_0
#   - defaults/noarch::nbformat==5.0.7=py_0
#   - conda-forge/osx-64::python_abi==3.8=1_cp38
#   - defaults/osx-64::mistune==0.8.4=py38h1de35cc_1001
#   - defaults/noarch::urllib3==1.25.9=py_0
#   - defaults/noarch::defusedxml==0.6.0=py_0
#   - defaults/osx-64::widgetsnbextension==3.5.1=py38_0
#   - defaults/noarch::colorama==0.4.3=py_0
#   - defaults/osx-64::pytest==5.4.3=py38_0
#   - defaults/noarch::dask==2.20.0=py_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/noarch::parso==0.7.0=py_0
#   - defaults/osx-64::clyent==1.2.2=py38_1
#   - defaults/osx-64::astroid==2.4.2=py38_0
#   - defaults/noarch::cloudpickle==1.5.0=py_0
#   - defaults/noarch::pyopenssl==19.1.0=py_1
#   - defaults/noarch::alabaster==0.7.12=py_0
#   - defaults/noarch::pytz==2020.1=py_0
#   - defaults/noarch::fsspec==0.7.4=py_0
#   - defaults/osx-64::psutil==5.7.0=py38h1de35cc_0
#   - defaults/noarch::pathtools==0.1.2=py_1
#   - defaults/noarch::babel==2.8.0=py_0
#   - defaults/osx-64::pyrsistent==0.16.0=py38h1de35cc_0
#   - defaults/noarch::sphinxcontrib-websupport==1.2.3=py_0
#   - defaults/osx-64::ipython==7.16.1=py38h5ca1d4c_0
#   - defaults/osx-64::markupsafe==1.1.1=py38h1de35cc_1
#   - defaults/noarch::jupyterlab_server==1.2.0=py_0
#   - defaults/noarch::attrs==19.3.0=py_0
#   - defaults/osx-64::pkginfo==1.5.0.1=py38_0
#   - defaults/osx-64::gevent==20.6.2=py38haf1e3a3_0
#   - defaults/osx-64::locket==0.2.0=py38_1
#   - defaults/osx-64::pathlib2==2.3.5=py38_1
#   - defaults/osx-64::notebook==6.0.3=py38_0
#   - defaults/osx-64::h5py==2.10.0=py38h3134771_0
#   - defaults/osx-64::watchdog==0.10.3=py38haf1e3a3_0
#   - defaults/noarch::heapdict==1.0.1=py_0
#   - defaults/noarch::diff-match-patch==20200713=py_0
#   - defaults/noarch::toml==0.10.1=py_0
#   - defaults/noarch::sphinxcontrib-applehelp==1.0.2=py_0
#   - defaults/noarch::typing_extensions==3.7.4.2=py_0
#   - defaults/osx-64::ruamel_yaml==0.15.87=py38haf1e3a3_1
#   - defaults/noarch::qdarkstyle==2.8.1=py_0
#   - defaults/osx-64::jupyter==1.0.0=py38_7
#   - defaults/osx-64::gmpy2==2.0.8=py38h6ef4df4_3
#   - defaults/osx-64::scikit-image==0.16.2=py38h6c726b0_0
#   - defaults/osx-64::py-lief==0.10.1=py38haf313ee_0
#   - defaults/osx-64::path==13.1.0=py38_0
#   - defaults/noarch::pycparser==2.20=py_2
#   - defaults/noarch::pycodestyle==2.6.0=py_0
#   - defaults/osx-64::cytoolz==0.10.1=py38h1de35cc_0
#   - defaults/noarch::qtconsole==4.7.5=py_0
#   - defaults/noarch::seaborn==0.10.1=py_0
#   - defaults/noarch::et_xmlfile==1.0.1=py_1001
#   - defaults/noarch::tqdm==4.47.0=py_0
#   - defaults/osx-64::wurlitzer==2.0.1=py38_0
#   - defaults/osx-64::scikit-learn==0.23.1=py38h603561c_0
#   - defaults/noarch::rope==0.17.0=py_0
#   - defaults/noarch::click==7.1.2=py_0
#   - defaults/osx-64::bkcharts==0.2=py38_0
#   - defaults/noarch::xmltodict==0.12.0=py_0
#   - defaults/osx-64::python.app==2=py38_10
#   - defaults/noarch::backcall==0.2.0=py_0
#   - defaults/osx-64::numpy==1.18.5=py38h1da2735_0
#   - defaults/noarch::jdcal==1.4.1=py_0
#   - defaults/osx-64::python==3.8.3=h26836e1_2
#   - defaults/osx-64::fastcache==1.1.0=py38h1de35cc_0
#   - defaults/osx-64::matplotlib==3.2.2=0
#   - defaults/noarch::sphinxcontrib-jsmath==1.0.1=py_0
#   - defaults/osx-64::anaconda-navigator==1.9.12=py38_0
#   - defaults/noarch::jupyterlab==2.1.5=py_0
#   - defaults/osx-64::cffi==1.14.0=py38hc512035_1
#   - defaults/osx-64::ply==3.11=py38_0
#   - defaults/osx-64::pluggy==0.13.1=py38_0
#   - defaults/osx-64::bitarray==1.4.0=py38haf1e3a3_0
#   - defaults/noarch::applaunchservices==0.2.1=py_0
#   - defaults/noarch::zipp==3.1.0=py_0
#   - defaults/noarch::requests==2.24.0=py_0
#   - defaults/osx-64::zope==1.0=py38_1
#   - defaults/noarch::flask==1.1.2=py_0
#   - defaults/osx-64::nbconvert==5.6.1=py38_1
#   - defaults/osx-64::sip==4.19.8=py38h0a44026_0
#   - defaults/noarch::bleach==3.1.5=py_0
#   - defaults/osx-64::conda==4.8.4=py38_0
#   - defaults/osx-64::lxml==4.5.2=py38h63b7cb6_0
#   - defaults/osx-64::tornado==6.0.4=py38h1de35cc_1
#   - defaults/noarch::imagesize==1.2.0=py_0
#   - defaults/osx-64::lazy-object-proxy==1.4.3=py38h1de35cc_0
#   - defaults/noarch::filelock==3.0.12=py_0
#   - defaults/noarch::html5lib==1.1=py_0
#   - defaults/osx-64::ujson==1.35=py38h1de35cc_0
#   - defaults/noarch::flake8==3.8.3=py_0
#   - defaults/osx-64::zope.event==4.4=py38_0
#   - defaults/osx-64::mpmath==1.1.0=py38_0
#   - defaults/noarch::joblib==0.16.0=py_0
#   - defaults/osx-64::spyder-kernels==1.9.2=py38_0
#   - defaults/noarch::prompt_toolkit==3.0.5=0
#   - defaults/osx-64::pexpect==4.8.0=py38_1
#   - defaults/noarch::python-dateutil==2.8.1=py_0
#   - defaults/noarch::prompt-toolkit==3.0.5=py_0
#   - defaults/noarch::backports.weakref==1.0.post1=py_1
#   - defaults/osx-64::pytables==3.6.1=py38h4727e94_0
#   - defaults/osx-64::ipython_genutils==0.2.0=py38_0
#   - defaults/noarch::qtpy==1.9.0=py_0
#   - defaults/osx-64::mkl-service==2.3.0=py38hfbe908c_0
#   - defaults/osx-64::future==0.18.2=py38_1
#   - defaults/noarch::zict==2.0.0=py_0
# done
#
# ## Package Plan ##
#
#   environment location: /Applications/anaconda3
#
#   added / updated specs:
#     - jsonschema
#
#
# The following NEW packages will be INSTALLED:
#
#   pandas             pkgs/main/osx-64::pandas-1.0.5-py38h959d312_0
#   setuptools         pkgs/main/osx-64::setuptools-49.2.0-py38_0
#
#
# Preparing transaction: done
# Verifying transaction: failed
#
# RemoveError: 'setuptools' is a dependency of conda and cannot be removed from
# conda's operating environment.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pyflux

# %%
conda install mesa pickle json sklearn xlrd recommonmark
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - json
#   - pickle
#   - sklearn
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://conda.anaconda.org/conda-forge/osx-64
#   - https://conda.anaconda.org/conda-forge/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install geopandas

# %%
conda install covid_abm

# %%
# %load_ext autotime

# %%
import os
os.getcwd()

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
import numpy as np
from collections import Counter

from covid19_abm.dir_manager import get_data_dir

# %%
age_map = {
    'less than 1 year': 0,
    'less than 1 year ': 0,
    '1 year': 1,
    '1 year ': 1,
    '2 years': 2,
    '2 years ': 2,
    '98': 98,
    '98 ': 98,
    'not reported/missing': None,
    'not reported/missing ': None,
}

econ_stat_map = {
    'Not working, inactive, not': 'Not working, inactive, not in universe',
}

# %%
full_individual_df = pd.read_stata(
    get_data_dir('raw', 'census', 'ABM_Simulated_Pop_WardDistributed_UpdatedMay30_school_complete_060520.dta'))

# %%
full_individual_df['age'] = full_individual_df['age'].map(lambda x: age_map.get(x, x))
full_individual_df['economic_status'] = full_individual_df['economic_status'].str.strip().map(lambda x: econ_stat_map.get(x, x))

# %%
full_individual_df.head()

# %%
l = '''Not working, inactive, not in universe
In School
Homemakers/Housework
Office workers
Service Workers
Agriculture Workers
Indusrtry Workers
In the army
Disabled and not working'''
l = l.split('\n')
full_individual_df['economic_status'].value_counts()[l]

# %% [markdown]
# # Fill unknown age

# %%
individual_df = full_individual_df

# %%
# missing_val = 'not reported/missing'
age_cols = ['geo1_zw2012', 'urban', 'persons', 'sex', 'marst', 'citizen', 'race', 'disabled', 'economic_status']
X = pd.get_dummies(individual_df[age_cols], drop_first=True)

X_train = X[individual_df['age'].notnull()]

# %%
gb = GradientBoostingRegressor(n_estimators=100, max_depth=3, random_state=1029)
# rf = RandomForestRegressor(n_estimators=100, max_depth=3, random_state=1029, n_jobs=50)

frac = 0.05
X_tr = X_train.sample(frac=frac, random_state=1029)
gb.fit(X_tr, individual_df.loc[X_tr.index, 'age'])

missing_age = X[individual_df['age'].isnull()]

# %%
pd.Series(gb.predict(missing_age)).hist()

# %%
X_tr.shape

# %%
individual_df.loc[missing_age.index, 'age'] = gb.predict(missing_age).astype(int)
individual_df.loc[missing_age.index].head()

# %%
individual_df.economic_status.astype(str).value_counts()

# %% [markdown]
# ## Create `ward_id`, `household_id` and `economic_activity_location_id`

# %%
relevant_cols = [
    'person_id', 'age', 'sex',
    'household_id', 'ward_id',
    'economic_status', 'economic_activity_location_id',
    # 'household', 'ward'
]

# %%
old_new_districts = pd.read_csv(
    get_data_dir('raw', 'district_relation.csv', index_col=0))
old_new_districts.index = old_new_districts['ADMIN_NAME'].str.lower()

# %%
individual_df['serial_expanded'] = individual_df['serial']

# %%
individual_df['household_id'] = individual_df['serial_expanded'].map(lambda x: f'h_{x}')
individual_df['old_ward_id'] = individual_df['geo2_zw2012'].map(lambda x: f'w_{old_new_districts["DIST2012"][x]}')                                          
individual_df['new_ward_id'] = individual_df['geo2_zw2012'].map(lambda x: f'w_{old_new_districts["NEW_DIST_ID_2"][x]}')

# %%
expanded_individual_df = individual_df.copy()

# %%
expanded_individual_df.head()

# %%
expanded_individual_df['school_goers'] = 1 * (expanded_individual_df['school_goers'] != 0)

# %%
expanded_individual_df.columns

# %%
expanded_individual_df.groupby('serial')['sex'].count().mean()

# %%
expanded_individual_df.shape[0] / expanded_individual_df['serial'].nunique()

# %%
(expanded_individual_df['school_goers'] == 1).sum()

# %%
(expanded_individual_df['school_goers'] == 1).sum()

# %% [markdown]
# # Mining

# %%
# relevant_cols = [
#     'person_id', 'age', 'sex',
#     'household_id', 'ward_id',
#     'economic_status', 'economic_activity_location_id',
#     'school_id_district', 
#     'manufacturing_workers',
#     'mining_district_id'
#     # 'household', 'ward'
# ]

relevant_cols = [
    'person_id', 'age', 'sex',
    'household_id', 'ward_id',
    'economic_status', 'economic_activity_location_id',
    # 'school_id_district', 
    'school_goers',
    'manufacturing_workers',
    # 'mining_district_id'
    # 'household', 'ward'
]

# %%
mining_df = expanded_individual_df.copy()

p = mining_df['economic_status']

mining_df.loc[p == 'Disabled and not working', 'economic_activity_location_id'] = mining_df.loc[p == 'Disabled and not working', 'household_id']
mining_df.loc[p != 'Disabled and not working', 'economic_activity_location_id'] = mining_df.loc[p != 'Disabled and not working', 'new_ward_id']

try:
    mining_df.drop('person_id', axis=1, inplace=True)
except KeyError:
    pass

mining_df['person_id'] = mining_df.index
mining_df['age'] = mining_df['age'].astype(int)
mining_df['economic_status'] = mining_df['economic_status'].str.strip()
mining_df.rename(columns={'new_ward_id': 'ward_id'}, inplace=True)

mining_df[relevant_cols].to_pickle(
    get_data_dir('preprocessed', 'census', 'zimbabwe_ipums_mining_manufacturing_school_new_dist_100pct.pickle'))

# %%
mining_df[relevant_cols].head()

# %% [markdown]
# # Contingent on available data

# %%
# mining_df['serial_expanded'] = mining_df['serial'].map(lambda x: f'{x}_01')
# mining_df['household_id'] = mining_df['serial_expanded'].map(lambda x: f'h_{x}')
mining_df.loc[mining_df['mining_district_id'] != '', 'mining_district_id'] = mining_df.loc[mining_df['mining_district_id'] != '', 'mining_district_id'].map(lambda x: f'mining_{x}')
mining_df.loc[mining_df['school_id_district'] != '', 'school_id_district'] = mining_df.loc[mining_df['school_id_district'] != '', 'school_id_district'].map(lambda x: f'school_{x}')

# %%
mining_df.head()

# %%
p = mining_df['economic_status']

mining_df.loc[p == 'Disabled and not working', 'economic_activity_location_id'] = mining_df.loc[p == 'Disabled and not working', 'household_id']
mining_df.loc[p != 'Disabled and not working', 'economic_activity_location_id'] = mining_df.loc[p != 'Disabled and not working', 'new_ward_id']

# %%
try:
    mining_df.drop('person_id', axis=1, inplace=True)
except KeyError:
    pass

mining_df['person_id'] = mining_df.index
mining_df['age'] = mining_df['age'].astype(int)
mining_df['economic_status'] = mining_df['economic_status'].str.strip()
mining_df.rename(columns={'new_ward_id': 'ward_id'}, inplace=True)

# %%
mining_df[relevant_cols][
    mining_df.serial_expanded.str.endswith('_01')
].to_pickle('../../data/zimbabwe_ipums_mining_manufacturing_school_new_dist_5pct.pickle')

# %%
mining_df[relevant_cols][
    mining_df.serial_expanded.str.endswith('_01') | mining_df.serial_expanded.str.endswith('_02')
].to_pickle('../../data/zimbabwe_ipums_mining_manufacturing_school_new_dist_10pct.pickle')

# %%
mining_df.shape

# %%
import pandas as pd

# %%
mining_df = pd.read_pickle('../../data/zimbabwe_ipums_mining_manufacturing_school_new_dist_10pct.pickle')

# %%
mining_df[mining_df['school_id_district'] != '']['person_id']

# %% [markdown]
# # Expand to 10%

# %%
mining_df

# %% [markdown]
# # Scratch

# %%
mining_df[~mining_df['household_id'].str.startswith('h_')]['person_id'].values

# %%
mining_df[mining_df.manufacturing_workers.notnull()].person_id

# %%
mining_df[mining_df['manufacturing_workers'].notnull()]['person_id'].values

# %%
mining_df[mining_df['school_id_district'] != '']['person_id'].values

# %%
mining_df['school_id_district'].shape
